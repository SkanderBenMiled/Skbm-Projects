# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import plotly.express as px


def scrape_aziza_homepage():
    url = "https://aziza.tn/fr/home"
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        print("Page successfully fetched!")
        soup = BeautifulSoup(response.content, "html.parser")
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        return pd.DataFrame()

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="fr">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="مغازات عزيزة - Magasins Aziza" name="title"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    مغازات عزيزة - Magasins Aziza
#   </title>
#   <link href="https://aziza.tn/static/version1707842367/_cache/merged/9fcd907111566c85d42b3ea8b244423d.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://aziza.tn/static/version1707842367/frontend/Sm/market_magasin/fr_FR/css/styles-l.min.css" media="screen and (min-width: 768px)" rel="stylesheet" type="text/css"/>
#   <link href="https://aziza.tn/static/version1707842367/frontend/Sm/market_magasin/fr_FR/css/print.min.css" media="print" rel="stylesheet" type="text/css"/>
#   <link href="https://aziza.tn/media/favicon/stores/1/favicon.png" rel="icon" type="image/x-icon"/>
#   <link href="https://aziza.tn/media/favicon/stores/1/favicon.png" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="aeafysofxyokeun2bzh5mj6bnn690b" name="facebook-domain-verification"/>
#   <meta content="xUOOfenkIN8nQYs0SLSlQodugLx_MZPEzbp0Yk-opn4" name="google-site-verification"/>
#   <!-- Google Tag Manager -->
#   <!-- End Google Tag Manager -->
#   <!-- Meta Business Extension for Magento 2 -->
#   <!-- Meta Pixel Code -->
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=1767832930330338&amp;ev=PageView&amp;noscript=1&amp;a=magento2-0.0.0-1.4.6" style="display:none" width="1"/>
#   </noscript>
#   <!-- End Meta Pixel Code -->
#   <!-- BEGIN GOOGLE ANALYTICS CODE -->
#   <!-- END GOOGLE ANALYTICS CODE -->
#   <!-- BEGIN GOOGLE VERIFICATION TAG -->
#   <!-- END GOOGLE VERIFICATION TAG -->
#   <!-- BEGIN GTAG GLOBAL TAG -->
#   <!-- END GTAG GLOBAL TAG -->
#   <!--CUSTOM CSS-->
#   <style>
#   </style>
#   <!--CUSTOM JS-->
#   <!--LISTING CONFIG-->
#   <style>
#    {
#     font-family:
# Aclonica;
# }
#
# @media (min-width: 1200px) {
#
#     .container {
#         width: 1280px;
#         max-width: 1280px;
#     }
#
#     /*==1 COLUMN==*/
#
#     .col1-layout .category-product.products-grid .item {
#         width: 25%;
#     }
#
#     .col1-layout .category-product.products-grid .item:nth-child(4n+1) {
#         clear: both;
#     }
#
#     /*==2 COLUMNS==*/
#
#     .col2-layout .category-product.products-grid .item {
#         width: 25%;
#     }
#
#     .col2-layout .category-product.products-grid .item:nth-child(4n+1) {
#         clear: both;
#     }
#
#     /*==3 COLUMNS==*/
#
#     .col3-layout .category-product.products-grid .item {
#         width: 50%;
#     }
#
#     .col3-layout .category-product.products-grid .item:nth-child(2n+1) {
#         clear: both;
#     }
# }
#
# @media (min-width: 992px) and (max-width: 1199px) {
#
#     /*==1 COLUMN==*/
#
#     .col1-layout .category-product.products-grid .item {
#         width: 25%;
#     }
#
#     .col1-layout .category-product.products-grid .item:nth-child(4n+1) {
#         clear: both;
#     }
#
#     /*==2 COLUMNS==*/
#
#     .col2-layout .category-product.products-grid .item {
#         width: 25%;
#     }
#
#     .col2-layout .category-product.products-grid .item:nth-child(4n+1) {
#         clear: both;
#     }
#
#     /*==3 COLUMNS==*/
#
#     .col3-layout .category-product.products-grid .item {
#         width: 100%;
#     }
#
#     .col3-layout .category-product.products-grid .item:nth-child(1n+1) {
#         clear: both;
#     }
# }
#
# @media (min-width: 768px) and (max-width: 991px) {
#
#     /*==1 COLUMN==*/
#
#     .col1-layout .category-product.products-grid .item {
#         width: 33.333333333333%;
#     }
#
#     .col1-layout .category-product.products-grid .item:nth-child(3n+1) {
#         clear: both;
#     }
#
#     /*==2 COLUMNS==*/
#
#     .col2-layout .category-product.products-grid .item {
#         width: 33.333333333333%;
#     }
#
#     .col2-layout .category-product.products-grid .item:nth-child(3n+1) {
#         clear: both;
#     }
#
#     /*==3 COLUMNS==*/
#
#     .col3-layout .category-product.products-grid .item {
#         width: 100%;
#     }
#
#     .col3-layout .category-product.products-grid .item:nth-child(1n+1) {
#         clear: both;
#     }
# }
#
# @media (min-width: 481px) and (max-width: 767px) {
#
#     /*==1 COLUMN==*/
#
#     .col1-layout .category-product.products-grid .item {
#         width: 50%;
#     }
#
#     .col1-layout .category-product.products-grid .item:nth-child(2n+1) {
#         clear: both;
#     }
#
#     /*==2 COLUMNS==*/
#
#     .col2-layout .category-product.products-grid .item {
#         width: 50%;
#     }
#
#     .col2-layout .category-product.products-grid .item:nth-child(2n+1) {
#         clear: both;
#     }
#
#     /*==3 COLUMNS==*/
#
#     .col3-layout .category-product.products-grid .item {
#         width: 100%;
#     }
#
#     .col3-layout .category-product.products-grid .item:nth-child(1n+1) {
#         clear: both;
#     }
# }
#
# @media (max-width: 480px) {
#
#     /*==1 COLUMN==*/
#
#     .col1-layout .category-product.products-grid .item {
#         width: 100%;
#     }
#
#     .col1-layout .category-product.products-grid .item:nth-child(1n+1) {
#         clear: both;
#     }
#
#     /*==2 COLUMNS==*/
#
#     .col2-layout .category-product.products-grid .item {
#         width: 100%;
#     }
#
#     .col2-layout .category-product.products-grid .item:nth-child(1n+1) {
#         clear: both;
#     }
#
#     /*==3 COLUMNS==*/
#
#     .col3-layout .category-product.products-grid .item {
#         width: 100%;
#     }
#
#     .col3-layout .category-product.products-grid .item:nth-child(1n+1) {
#         clear: both;
#     }
# }
#   </style>
#  </head>
#  <body class="header-9-style home-9-style footer-1-style layout-full_width cms-home cms-page-view page-layout-1column" data-container="body" data-mage-init='{"loaderAjax": {}, "loader": { "icon": "https://aziza.tn/static/version1707842367/frontend/Sm/market_magasin/fr_FR/images/loader-2.gif"}}'>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-T73QVWPB" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <noscript>
#    <div class="message global noscript">
#     <div class="content">
#      <p>
#       <strong>
#        Javascript est désactivé dans votre navigateur.
#       </strong>
#       <span>
#        Pour une meilleure expérience sur notre site, assurez-vous d’activer JavaScript dans votre navigateur.
#       </span>
#      </p>
#     </div>
#    </div>
#   </noscript>
#   <!-- BEGIN GTAG CART SCRIPT -->
#   <!-- END GTAG CART SCRIPT -->
#   <div class="page-wrapper">
#    <style>
#     .header-style-9 .header-top .header-top-links .toplinks-wrapper .header.links li a ,
# .header-style-9 .header-middle .minicart-header .minicart-content .cart-wrapper .minicart-wrapper .showcart{
#     pointer-events: none !important;
# }
#
# .modal-slide._inner-scroll .modal-footer {
#     display: none;
# }
#
# .modal-popup .action-close:before, .modal-slide .action-close:before{
#     font-weight: bold;
#     color: #e2101a ;
#     font-size: 42px!important;
# }
#
# .header-top .sm_megamenu_wrapper_horizontal_menu .sm_megamenu_lv1:nth-child(3):hover .sm_megamenu_head{
#  pointer-events: none;
# }
#
# @media (min-width: 768px) {
# body._has-modal .modal-popup._inner-scroll .modal-inner-wrap {
#     max-height: 90% !important;
#     width: 30%!important;
#     margin-top: 120px;
# }
# }
# @media (min-width: 1200px) {
# body._has-modal .modal-popup._inner-scroll .modal-inner-wrap {
#     max-height: 90% !important;
#     margin-top: 120px;
# }
#
# .modal-content a img{
#     width: 100%;
# }
#
# }
# .toolbar .modes .modes-mode.mode-list {
#     display: none;
# }
# @media (max-width: 767px){
#
# .modal-popup.modal-slide._inner-scroll .modal-inner-wrap {
#     height: auto;
#     min-height: auto !important;
# }
# .modal-popup.modal-slide .modal-inner-wrap[class] {
#     background-color: #fff !important;
# }
#
# }
# * {box-sizing: border-box}
# body {font-family: Verdana, sans-serif; margin:0}
# .mySlides {display: none}
# img {vertical-align: middle;}
#
# /* Slideshow container */
# .slideshow-container {
#   max-width: 1000px;
#   position: relative;
#   margin: auto;
# }
#
# /* Next & previous buttons */
# .prev, .next {
#   cursor: pointer;
#   position: absolute;
#   top: 50%;
#   width: auto;
#   padding: 16px;
#   margin-top: -22px;
#   color: white;
#   font-weight: bold;
#   font-size: 18px;
#   transition: 0.6s ease;
#   border-radius: 0 3px 3px 0;
#   user-select: none;
# }
#
# /* Position the "next button" to the right */
# .next {
#   right: 0;
#   border-radius: 3px 0 0 3px;
# }
#
# /* On hover, add a black background color with a little bit see-through */
# .prev:hover, .next:hover {
#   background-color: rgba(0,0,0,0.8);
# }
#
# /* Caption text */
# .text {
#   color: #f2f2f2;
#   font-size: 15px;
#   padding: 8px 12px;
#   position: absolute;
#   bottom: 8px;
#   width: 100%;
#   text-align: center;
# }
#
# /* Number text (1/3 etc) */
# .numbertext {
#   color: #f2f2f2;
#   font-size: 12px;
#   padding: 8px 12px;
#   position: absolute;
#   top: 0;
# }
#
# /* The dots/bullets/indicators */
# .dot {
#   cursor: pointer;
#   height: 15px;
#   width: 15px;
#   margin: 0 2px;
#   background-color: #ffd400;
#   border-radius: 50%;
#   display: inline-block;
#   transition: background-color 0.6s ease;
#   position: relative;
#   top:15px
# }
#
# .dot:hover {
#   background-color: #ffd400;
#   opacity: 0.5;
# }
#
# .tabs .tab-content {
#   position: relative !important;
# }
# .cms-aziza-recrute input,
# .cms-aziza-recrute select {
#     border: none;
#     height: 17px!important;
# }
#
# .header-style-9 .header-middle .search-header {
#     display: none;
# }
# @media (max-width: 1199px) {
#     .header-style-9 .header-top .header-top-links
#      .toplinks-wrapper .header.links li:first-child {
#         display: none;
#     }
#   }
#   .product-item-info .super {
#     z-index: 1;
#     position: absolute;
# }
#
# @media only screen and (max-width: 767px) {
#     .modal-popup.modal-slide {
#       left: 0;
#     }
#     .modal-slide, .modal-popup {
#     top: 20%;
# }
# }
#    </style>
#    <style>
#     .header-style-9 .header-top .header-top-links .toplinks-wrapper .header.links li a.account-icon:before {content: '\f007' !important;}
#     .block.block-dashboard-addresses {display: block !important;}
#    </style>
#    <div class="header-container header-style-9">
#     <div class="header-top">
#      <div class="container">
#       <div class="row row-topheader">
#        <nav class="sm_megamenu_wrapper_horizontal_menu sambar" data-sam="14242967551744457325" id="sm_megamenu_menu67fa4e6d9a144">
#         <div class="sambar-inner">
#          <span class="btn-sambar" data-href="#sm_megamenu_menu67fa4e6d9a144" data-sapi="collapse">
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#          </span>
#          <div class="mega-content">
#           <ul class="horizontal-type sm-megamenu-hover sm_megamenu_menu sm_megamenu_menu_black" data-jsapi="on">
#            <li class="other-toggle sm_megamenu_lv1 sm_megamenu_drop parent">
#             <a class="sm_megamenu_head sm_megamenu_drop" href="http://aziza.tn/fr/nos-magasins" id="sm_megamenu_73">
#              <span class="sm_megamenu_icon sm_megamenu_nodesc">
#               <span class="sm_megamenu_title">
#                Nos Magasins
#               </span>
#              </span>
#             </a>
#             <li class="other-toggle sm_megamenu_lv1 sm_megamenu_drop parent">
#              <a class="sm_megamenu_head sm_megamenu_drop" href="http://aziza.tn/fr/catalogues-pdf" id="sm_megamenu_74">
#               <span class="sm_megamenu_icon sm_megamenu_nodesc">
#                <span class="sm_megamenu_title">
#                 Catalogue
#                </span>
#               </span>
#              </a>
#              <li class="other-toggle sm_megamenu_lv1 sm_megamenu_drop parent">
#               <a class="sm_megamenu_head sm_megamenu_drop" href="http://www.azizacarriere.tn" id="sm_megamenu_170" target="_blank">
#                <span class="sm_megamenu_icon sm_megamenu_nodesc">
#                 <span class="sm_megamenu_title">
#                  Carrières
#                 </span>
#                </span>
#               </a>
#              </li>
#             </li>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </nav>
#        <div class="header-top-links">
#         <div class="toplinks-wrapper">
#          <ul class="header links">
#           <li>
#            <a class="account-icon" href="https://aziza.tn/fr/" title="My Account">
#            </a>
#           </li>
#           <li class="link wishlist" data-bind="scope: 'wishlist'">
#            <a href="https://aziza.tn/fr/wishlist/" title="Ma liste de courses">
#             Ma liste d’envies
#             <!-- ko if: wishlist().counter -->
#             <span class="counter qty" data-bind="text: wishlist().counter">
#             </span>
#             <!-- /ko -->
#            </a>
#           </li>
#           <li class="myaccount-link">
#            <a href="https://aziza.tn/fr/customer/account/" title="Mon compte">
#             Mon compte
#            </a>
#           </li>
#           <li class="authorization-link" data-label="ou">
#            <a href="https://aziza.tn/fr/customer/account/login/referer/aHR0cHM6Ly9heml6YS50bi9mci9ob21l/" title="Connecter / Déconnecter">
#             Connexion
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="name-customer">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="header-middle">
#      <div class="container">
#       <div class="middle-content">
#        <div class="row">
#         <div class="col-lg-4 logo-header">
#          <div class="logo-wrapper">
#           <a class="logo" href="https://aziza.tn/fr/home/" title="Aziza">
#            <img alt="Aziza" height="95" src="https://aziza.tn/media/logo/stores/1/logo-aziza.png" width="475"/>
#           </a>
#          </div>
#         </div>
#         <div class="col-lg-8 header-middle-right">
#          <div class="minicart-header">
#           <div class="minicart-content">
#            <div class="cart-wrapper">
#             <div class="minicart-wrapper" data-block="minicart">
#              <a class="action showcart" data-bind="scope: 'minicart_content'" href="https://aziza.tn/fr/checkout/cart/">
#               <span class="text">
#                <span class="df-text">
#                 Panier
#                </span>
#                <span class="hidden">
#                 My Cart -
#                </span>
#               </span>
#               <span class="counter qty empty" data-bind="css: { empty: !!getCartParam('summary_count') == false }, blockLoader: isLoading">
#                <span class="counter-number">
#                 <!-- ko text: getCartParam('summary_count') -->
#                 <!-- /ko -->
#                </span>
#                <span class="counter-label">
#                 <!-- ko if: getCartParam('summary_count') -->
#                 <!-- ko text: getCartParam('summary_count') -->
#                 <!-- /ko -->
#                 <!-- ko i18n: 'items' -->
#                 <!-- /ko -->
#                 <!-- /ko -->
#                 <!-- ko if: getCartParam('summary_count') == 0 -->
#                 <!-- ko i18n: '0 item' -->
#                 <!-- /ko -->
#                 <!-- /ko -->
#                </span>
#                <span class="price-minicart">
#                 <!-- ko foreach: getRegion('subtotalContainer') -->
#                 <!-- ko template: getTemplate() -->
#                 <!-- /ko -->
#                 <!-- /ko -->
#                </span>
#               </span>
#              </a>
#              <div class="block block-minicart empty" data-mage-init='{"dropdownDialog":{
#                 "appendTo":"[data-block=minicart]",
#                 "triggerTarget":".showcart",
#                 "timeout": "2000",
#                 "closeOnMouseLeave": false,
#                 "closeOnEscape": true,
#                 "triggerClass":"active",
#                 "parentClass":"active",
#                 "buttons":[]}}' data-role="dropdownDialog">
#               <div data-bind="scope: 'minicart_content'" id="minicart-content-wrapper">
#                <!-- ko template: getTemplate() -->
#                <!-- /ko -->
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="search-header">
#           <div class="search-wrapper">
#            <div class="lof-autosearch box search_box" id="lof-search2121838071744460779">
#             <form action="https://aziza.tn/fr/catalogsearch/result/" id="formlof-search2121838071744460779" method="GET">
#              <div class="lof-search control" id="autosearch2121838071744460779">
#               <input autocomplete="off" class="input-text ui-autocomplete-input" name="q" placeholder="Rechercher..." type="text" value=""/>
#               <button class="button-search fa fa-search">
#               </button>
#              </div>
#             </form>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="header-bottom">
#      <div class="container">
#       <div class="row">
#        <div class="sidebar-megamenu">
#         <div class="megamenu-content-sidebar">
#          <div class="btn-megamenu">
#           <a href="javascript:void(0)" title="Ventes en ligne">
#            Accueil
#           </a>
#          </div>
#          <div class="menu-ver-content">
#           <div class="navigation-megamenu-wrapper">
#            <p class="note-msg">
#             There are no items matching the selection.
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="navigation-mobile-container">
#          <!--COLLAPSE-->
#          <!--SIDEBAR-->
#          <div class="nav-mobile-container sidebar-type">
#           <div class="btn-mobile">
#            <a class="button-mobile sidebar-nav" id="sidebar-button" title="Catégories">
#             <i class="fa fa-bars">
#             </i>
#             <span class="hidden">
#              Catégories
#             </span>
#            </a>
#           </div>
#           <nav class="navigation-mobile" id="navigation-mobile">
#           </nav>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="catalogue-modal" style="display: none">
#    </div>
#    <div id="popup-modal">
#     <div class="slideshow-container">
#      <div class="mySlides">
#       <a href="https://aziza.tn/jeu/jeux.php" target="_blank">
#        <img src="https://aziza.tn/pub/media/wysiwyg/popup-unilever.jpg" style="width:100%"/>
#       </a>
#      </div>
#      <!--
#  <div style="text-align:center">
#   <span class="dot" onclick="currentSlide(1)"></span>
#   <span class="dot" onclick="currentSlide(2)"></span>
#   <span class="dot" onclick="currentSlide(3)"></span>
#   <span class="dot" onclick="currentSlide(4)"></span>
# </div>
# -->
#     </div>
#    </div>
#    <main class="page-main" id="maincontent">
#     <a id="contentarea" tabindex="-1">
#     </a>
#     <div class="columns col1-layout">
#      <div class="container">
#       <div class="row">
#        <div class="col-lg-12 col-md-12">
#         <div class="page-title-wrapper">
#          <h1 class="page-title">
#           <span class="base" data-ui-id="page-title-wrapper">
#            Page d’accueil
#           </span>
#          </h1>
#         </div>
#         <div class="page messages">
#          <div data-placeholder="messages">
#          </div>
#          <div data-bind="scope: 'messages'">
#           <!-- ko if: cookieMessages && cookieMessages.length > 0 -->
#           <div class="messages" data-bind="foreach: { data: cookieMessages, as: 'message' }" role="alert">
#            <div data-bind="attr: {
#             class: 'message-' + message.type + ' ' + message.type + ' message',
#             'data-ui-id': 'message-' + message.type
#         }">
#             <div data-bind="html: $parent.prepareMessageForHtml(message.text)">
#             </div>
#            </div>
#           </div>
#           <!-- /ko -->
#           <!-- ko if: messages().messages && messages().messages.length > 0 -->
#           <div class="messages" data-bind="foreach: { data: messages().messages, as: 'message' }" role="alert">
#            <div data-bind="attr: {
#             class: 'message-' + message.type + ' ' + message.type + ' message',
#             'data-ui-id': 'message-' + message.type
#         }">
#             <div data-bind="html: $parent.prepareMessageForHtml(message.text)">
#             </div>
#            </div>
#           </div>
#           <!-- /ko -->
#          </div>
#         </div>
#         <div class="column main">
#          <input name="form_key" type="hidden" value="mHTdlhyclmrkB8EO"/>
#          <div data-bind="scope:'authenticationPopup'" id="authenticationPopup" style="display: none;">
#           <!-- ko template: getTemplate() -->
#           <!-- /ko -->
#          </div>
#          <style>
#           .page-main{padding: 0}.page-title .base{display: none}@media(min-width: 1200px) {    .page-layout-1column .block.widget .products-grid .product-item {        width: calc((100% - 9%)/7);    }}
#          </style>
#          <div class="home-page-9">
#           <div class="click">
#            <div id="topheader">
#             <div class="catalogues-fixed" id="fixed">
#              <div class="block-catalogues-fixed">
#               <div class="row">
#                <div class="col-lg-12 col-md-12 col-sm-12 col-xs-6">
#                 <div class="item catalogues-derniere">
#                  <div class="block-catalogue block widget block-products-list grid">
#                   <!--             <div class="block-title test">
#                 <strong>
#                                     </strong>
#             </div>
#             -->
#                   <div class="block-content">
#                    <!-- new_products_content_widget_grid-->
#                    <div class="products-grid grid">
#                     <ol class="product-items widget-product-grid">
#                      <li class="product-item btn">
#                       <div class="product-item-info 2025-04-02 00:00:00" id="catalogues-derniere-img-f">
#                        Semaine dernière
#                       </div>
#                      </li>
#                     </ol>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                 <div class="item catalogues-en-cours">
#                  <div class="block-catalogue block widget block-products-list grid">
#                   <!--             <div class="block-title test">
#                 <strong>
#                                     </strong>
#             </div>
#             -->
#                   <div class="block-content">
#                    <!-- new_products_content_widget_grid-->
#                    <div class="products-grid grid">
#                     <ol class="product-items widget-product-grid">
#                      <li class="product-item active btn">
#                       <div class="product-item-info 2025-04-09 00:00:00" id="catalogues-en-cours-img-f">
#                        Promos de la semaine
#                       </div>
#                      </li>
#                     </ol>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                 <div class="item catalogues-prochaine">
#                  <div class="block-catalogue block widget block-products-list grid">
#                   <!--             <div class="block-title test">
#                 <strong>
#                                     </strong>
#             </div>
#                      -->
#                  </div>
#                 </div>
#                 <div class="item catalogues-vente">
#                  <style>
#                   .block-catalogues .catalogues-vente .block-title strong {
#     color: #ffd400;
#     font-size: 14px!important;
#     padding: 5px;
# }
#
# .block-catalogues .catalogues-vente .block-title {
#     padding: 5px 0 0 !important;
# }
#
# .block-catalogues .catalogues-derniere .block-catalogue {
#     -webkit-box-shadow: 1px 5px 8px 0px #dbd6d6!important;
#     box-shadow: 1px 5px 8px 0px #dbd6d6!important;
#     transform: rotateY(0deg) skewY(0deg) translateX(0px);
#     -webkit-transform: scale(.8) translate(0%,4%);
# }
#
# .catalogues-vente img:hover {
#     opacity: .7;
#     filter: saturate(1.75);
# }
#
# .item.catalogues-vente  {
#     background-size: 100% 100% !important;
#     background-position: 0 34px !important;
# }
#
# .catalogues-vente img{
#     opacity: 1;
#     -webkit-transition: .3s ease-in-out;
#     transition: .3s ease-in-out;
# }
#                  </style>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="back-catalogues">
#              <div class="block-catalogues">
#               <div class="row">
#                <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#                 <div class="item catalogues-derniere">
#                  <div class="block-catalogue block widget block-products-list grid">
#                   <div class="block-content">
#                    <!-- new_products_content_widget_grid_top-->
#                    <div class="products-grid grid">
#                     <ol class="product-items widget-product-grid">
#                      <div class="block-title test">
#                       <strong>
#                        Semaine dernière
#                       </strong>
#                      </div>
#                      <li class="product-item btn">
#                       <div class="product-item-info 2025-04-02 00:00:00" id="catalogues-derniere-img">
#                        <span class="product-image-container">
#                         <span class="product-image-wrapper">
#                          <img alt="Promo de la semaine" class="product-image-photo" height="" src="https://aziza.tn/media/catalog/product/cache/1267a79388e844632696facf1a71b0a2/1/_/1_1ff6_75ee.jpg" width="">
#                          </img>
#                         </span>
#                        </span>
#                       </div>
#                      </li>
#                     </ol>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                 <div class="item catalogues-en-cours">
#                  <div class="block-catalogue block widget block-products-list grid">
#                   <div class="block-content">
#                    <!-- new_products_content_widget_grid_top-->
#                    <div class="products-grid grid">
#                     <ol class="product-items widget-product-grid">
#                      <div class="block-title test">
#                       <strong>
#                        Promos de la semaine
#                       </strong>
#                      </div>
#                      <li class="product-item active btn">
#                       <div class="product-item-info 2025-04-09 00:00:00" id="catalogues-en-cours-img">
#                        <span class="product-image-container">
#                         <span class="product-image-wrapper">
#                          <img alt="Mercredi prochain" class="product-image-photo" height="" src="https://aziza.tn/media/catalog/product/cache/1267a79388e844632696facf1a71b0a2/1/_/1_6de3.jpg" width=""/>
#                         </span>
#                        </span>
#                       </div>
#                      </li>
#                     </ol>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                 <div class="item catalogues-prochaine">
#                  <div class="block-catalogue block widget block-products-list grid">
#                  </div>
#                 </div>
#                 <div class="item catalogues-vente">
#                  <style>
#                   .block-catalogues .catalogues-vente .block-title strong {
#     color: #ffd400;
#     font-size: 14px!important;
#     padding: 5px;
# }
#
# .block-catalogues .catalogues-vente .block-title {
#     padding: 5px 0 0 !important;
# }
#
# .block-catalogues .catalogues-vente .block-catalogue {
#     -webkit-box-shadow: 1px 5px 8px 0px #dbd6d6!important;
#     box-shadow: 1px 5px 8px 0px #dbd6d6!important;
#     transform: rotateY(0deg) skewY(0deg) translateX(0px);
#     -webkit-transform: scale(.8) translate(0%,4%);
# }
#
# .catalogues-vente img:hover {
#     opacity: .7;
#     filter: saturate(1.75);
# }
#
# .item.catalogues-vente  {
#     background-size: 100% 100% !important;
#     background-position: 0 34px !important;
# }
#
# .catalogues-vente img{
#     opacity: 1;
#     -webkit-transition: .3s ease-in-out;
#     transition: .3s ease-in-out;
# }
#
# .item.catalogues-vente .block.widget .products-grid .product-item  {
#     min-width: 100% !important;
# }
#                  </style>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="arrival">
#             <div class="non-alimentaire">
#              <style>
#               .price-box.price-final_price {
#     margin-top: 15px !important;
# }
#              </style>
#              <div class="block widget block-products-list grid" id="grid-aN">
#               <div class="block-title">
#                <strong>
#                 Arrivage semaine
#                </strong>
#                du 09-04-2025 au 15-04-2025
#               </div>
#               <div class="block-content">
#                <!-- new_products_content_widget_grid-->
#                <div class="products-grid grid">
#                 <ol class="product-items widget-product-grid" id="list_products-aN">
#                  <li class="product-item">
#                   <div class="product-item-info 2025-04-09 00:00:00">
#                    <div class="super">
#                     <img ?="" src="../media/wysiwyg/superfriday.svg"/>
#                    </div>
#                    <a class="product-item-photo" href="https://aziza.tn/fr/10107638.html">
#                     <span class="product-image-container">
#                      <span class="product-image-wrapper">
#                       <img alt="Huile de colza" class="product-image-photo" height="" src="https://aziza.tn/media/catalog/product/cache/b5981f94a096ce8ed249e81adce0f478/1/0/101076381_dd40.jpg" width="">
#                       </img>
#                      </span>
#                     </span>
#                    </a>
#                    <div class="product-item-details">
#                     <div class="product-item-name">
#                      <h3 class="product name product-item-name product-name">
#                       <a class="product-item-link" href="https://aziza.tn/fr/10107638.html" title="Huile de colza">
#                        Huile de colza
#                       </a>
#                       <br/>
#                       <span class="more_title">
#                        5 L
#                       </span>
#                       <br/>
#                       <span class="brand">
#                        El Behi
#                       </span>
#                      </h3>
#                     </div>
#                     <div class="price-box price-final_price" data-price-box="product-id-15309" data-product-id="15309" data-role="priceBox">
#                      <span class="price-container price-final_price tax weee">
#                       <span class="ok price-wrapper" data-price-amount="21.9" data-price-type="finalPrice" id="old-price-15309-widget-product-grid">
#                        <span class="price">
#                         21,
#                         <span class="units">
#                          900
#                         </span>
#                        </span>
#                        <span class="currency">
#                         TND
#                        </span>
#                       </span>
#                      </span>
#                     </div>
#                     <div class="product-item-actions">
#                      <div class="actions-primary">
#                       <button class="tocart primary dispo" type="button">
#                        <span>
#                         <a href="https://aziza.tn/fr/10107638.html">
#                          Voir disponibilité
#                         </a>
#                        </span>
#                       </button>
#                      </div>
#                      <div class="actions-secondary" data-role="add-to-links">
#                       <a class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/aziza.tn\/fr\/wishlist\/index\/add\/","data":{"product":15309,"uenc":"aHR0cHM6Ly9heml6YS50bi9mci9ob21l"}}' href="#" title="Ajouter à ma liste d’envie">
#                        <span>
#                         Ajouter à ma liste d’envie
#                        </span>
#                       </a>
#                       <a class="action tocompare" data-post='{"action":"https:\/\/aziza.tn\/fr\/catalog\/product_compare\/add\/","data":{"product":"15309","uenc":"aHR0cHM6Ly9heml6YS50bi9mci9ob21l"}}' href="#" title="Ajouter au comparateur">
#                        <span>
#                         Ajouter au comparateur
#                        </span>
#                       </a>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="product-item">
#                   <div class="product-item-info 2025-04-09 00:00:00">
#                    <a class="product-item-photo" href="https://aziza.tn/fr/10087796.html">
#                     <span class="product-image-container">
#                      <span class="product-image-wrapper">
#                       <img alt="Pot de conservation en plastique" class="product-image-photo" height="" src="https://aziza.tn/media/catalog/product/cache/b5981f94a096ce8ed249e81adce0f478/1/0/100877961_d93f.jpg" width=""/>
#                      </span>
#                     </span>
#                    </a>
#                    <div class="product-item-details">
#                     <div class="product-item-name">
#                      <h3 class="product name product-item-name product-name">
#                       <a class="product-item-link" href="https://aziza.tn/fr/10087796.html" title="Pot de conservation en plastique">
#                        Pot de conservation en plastique
#                       </a>
#                       <br/>
#                       <span class="more_title">
#                        350 ML
#                       </span>
#                       <br/>
#                       <span class="brand">
#                       </span>
#                      </h3>
#                     </div>
#                     <div class="price-box price-final_price" data-price-box="product-id-10824" data-product-id="10824" data-role="priceBox">
#                      <span class="price-container price-final_price tax weee">
#                       <span class="ok price-wrapper" data-price-amount="0.9" data-price-type="finalPrice" id="old-price-10824-widget-product-grid">
#                        <span class="price">
#                         0,
#                         <span class="units">
#                          900
#                         </span>
#                        </span>
#                        <span class="currency">
#                         TND
#                        </span>
#                       </span>
#                      </span>
#                     </div>
#                     <div class="product-item-actions">
#                      <div class="actions-primary">
#                       <!--add safa 13-11-->
#                       <button class="tocart primary dispo" type="button">
#                        <span>
#                         <a href="https://aziza.tn/fr/10087796.html">
#                          Voir disponibilité
#                         </a>
#                        </span>
#                       </button>
#                      </div>
#                      <div class="actions-secondary" data-role="add-to-links">
#                       <a class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/aziza.tn\/fr\/wishlist\/index\/add\/","data":{"product":10824,"uenc":"aHR0cHM6Ly9heml6YS50bi9mci9ob21l"}}' href="#" title="Ajouter à ma liste d’envie">
#                        <span>
#                         Ajouter à ma liste d’envie
#                        </span>
#                       </a>
#                       <a class="action tocompare" data-post='{"action":"https:\/\/aziza.tn\/fr\/catalog\/product_compare\/add\/","data":{"product":"10824","uenc":"aHR0cHM6Ly9heml6YS50bi9mci9ob21l"}}' href="#" title="Ajouter au comparateur">
#                        <span>
#                         Ajouter au comparateur
#                        </span>
#                       </a>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="product-item">
#                   <div class="product-item-info 2025-04-09 00:00:00">
#                    <a class="product-item-photo" href="https://aziza.tn/fr/10087541.html">
#                     <span class="product-image-container">
#                      <span class="product-image-wrapper">
#                       <img alt="Pot de conservation  en plastique" class="product-image-photo" height="" src="https://aziza.tn/media/catalog/product/cache/b5981f94a096ce8ed249e81adce0f478/1/0/100875411_8893.jpg" width=""/>
#                      </span>
#                     </span>
#                    </a>
#                    <div class="product-item-details">
#                     <div class="product-item-name">
#                      <h3 class="product name product-item-name product-name">
#                       <a class="product-item-link" href="https://aziza.tn/fr/10087541.html" title="Pot de conservation  en plastique">
#                        Pot de conservation  en plastique
#                       </a>
#                       <br/>
#                       <span class="more_title">
#                        600 ML
#                       </span>
#                       <br/>
#                       <span class="brand">
#                       </span>
#                      </h3>
#                     </div>
#                     <div class="price-box price-final_price" data-price-box="product-id-10823" data-product-id="10823" data-role="priceBox">
#                      <span class="price-container price-final_price tax weee">
#                       <span class="ok price-wrapper" data-price-amount="1.1" data-price-type="finalPrice" id="old-price-10823-widget-product-grid">
#                        <span class="price">
#                         1,
#                         <span class="units">
#                          100
#                         </span>
#                        </span>
#                        <span class="currency">
#                         TND
#                        </span>
#                       </span>
#                      </span>
#                     </div>
#                     <div class="product-item-actions">
#                      <div class="actions-primary">
#                       <!--add safa 13-11-->
#                       <button class="tocart primary dispo" type="button">
#                        <span>
#                         <a href="https://aziza.tn/fr/10087541.html">
#                          Voir disponibilité
#                         </a>
#                        </span>
#                       </button>
#                      </div>
#                      <div class="actions-secondary" data-role="add-to-links">
#                       <a class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/aziza.tn\/fr\/wishlist\/index\/add\/","data":{"product":10823,"uenc":"aHR0cHM6Ly9heml6YS50bi9mci9ob21l"}}' href="#" title="Ajouter à ma liste d’envie">
#                        <span>
#                         Ajouter à ma liste d’envie
#                        </span>
#                       </a>
#                       <a class="action tocompare" data-post='{"action":"https:\/\/aziza.tn\/fr\/catalog\/product_compare\/add\/","data":{"product":"10823","uenc":"aHR0cHM6Ly9heml6YS50bi9mci9ob21l"}}' href="#" title="Ajouter au comparateur">
#                        <span>
#                         Ajouter au comparateur
#                        </span>
#                       </a>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="product-item">
#                   <div class="product-item-info 2025-04-09 00:00:00">
#                    <a class="product-item-photo" href="https://aziza.tn/fr/10107183.html">
#                     <span class="product-image-container">
#                      <span class="product-image-wrapper">
#                       <img alt="Bouteille  avec couvercle" class="product-image-photo" height="" src="https://aziza.tn/media/catalog/product/cache/b5981f94a096ce8ed249e81adce0f478/1/0/101071831_75b1.jpg" width=""/>
#                      </span>
#                     </span>
#                    </a>
#                    <div class="product-item-details">
#                     <div class="product-item-name">
#                      <h3 class="product name product-item-name product-name">
#                       <a class="product-item-link" href="https://aziza.tn/fr/10107183.html" title="Bouteille  avec couvercle">
#                        Bouteille  avec couvercle
#                       </a>
#                       <br/>
#                       <span class="more_title">
#                        0,250 L
#                       </span>
#                       <br/>
#                       <span class="brand">
#                       </span>
#                      </h3>
#                     </div>
#                     <div class="price-box price-final_price" data-price-box="product-id-15316" data-product-id="15316" data-role="priceBox">
#                      <span class="price-container price-final_price tax weee">
#                       <span class="ok price-wrapper" data-price-amount="1.1" data-price-type="finalPrice" id="old-price-15316-widget-product-grid">
#                        <span class="price">
#                         1,
#                         <span class="units">
#                          100
#                         </span>
#                        </span>
#                        <span class="currency">
#                         TND
#                        </span>
#                       </span>
#                      </span>
#                     </div>
#                     <div class="product-item-actions">
#                      <div class="actions-primary">
#                       <!--add safa 13-11-->
#                       <button class="tocart primary dispo" type="button">
#                        <span>
#                         <a href="https://aziza.tn/fr/10107183.html">
#                          Voir disponibilité
#                         </a>
#                        </span>
#                       </button>
#                      </div>
#                      <div class="actions-secondary" data-role="add-to-links">
#                       <a class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/aziza.tn\/fr\/wishlist\/index\/add\/","data":{"product":15316,"uenc":"aHR0cHM6Ly9heml6YS50bi9mci9ob21l"}}' href="#" title="Ajouter à ma liste d’envie">
#                        <span>
#                         Ajouter à ma liste d’envie
#                        </span>
#                       </a>
#                       <a class="action tocompare" data-post='{"action":"https:\/\/aziza.tn\/fr\/catalog\/product_compare\/add\/","data":{"product":"15316","uenc":"aHR0cHM6Ly9heml6YS50bi9mci9ob21l"}}' href="#" title="Ajouter au comparateur">
#                        <span>
#                         Ajouter au comparateur
#                        </span>
#                       </a>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="product-item">
#                   <div class="product-item-info 2025-04-09 00:00:00">
#                    <a class="product-item-photo" href="https://aziza.tn/fr/10055166.html">
#                     <span class="product-image-container">
#                      <span class="product-image-wrapper">
#                       <img alt="Organisateur tiroir" class="product-image-photo" height="" src="https://aziza.tn/media/catalog/product/cache/b5981f94a096ce8ed249e81adce0f478/1/0/100551661_5f28.jpg" width=""/>
#                      </span>
#                     </span>
#                    </a>
#                    <div class="product-item-details">
#                     <div class="product-item-name">
#                      <h3 class="product name product-item-name product-name">
#                       <a class="product-item-link" href="https://aziza.tn/fr/10055166.html" title="Organisateur tiroir">
#                        Organisateur tiroir
#                       </a>
#                       <br/>
#                       <span class="more_title">
#                       </span>
#                       <br/>
#                       <span class="brand">
#                       </span>
#                      </h3>
#                     </div>
#                     <div class="price-box price-final_price" data-price-box="product-id-2342" data-product-id="2342" data-role="priceBox">
#                      <span class="price-container price-final_price tax weee">
#                       <span class="ok price-wrapper" data-price-amount="1.59" data-price-type="finalPrice" id="old-price-2342-widget-product-grid">
#                        <span class="price">
#                         1,
#                         <span class="units">
#                          590
#                         </span>
#                        </span>
#                        <span class="currency">
#                         TND
#                        </span>
#                       </span>
#                      </span>
#                     </div>
#                     <div class="product-item-actions">
#                      <div class="actions-primary">
#                       <!--add safa 13-11-->
#                       <button class="tocart primary dispo" type="button">
#                        <span>
#                         <a href="https://aziza.tn/fr/10055166.html">
#                          Voir disponibilité
#                         </a>
#                        </span>
#                       </button>
#                      </div>
#                      <div class="actions-secondary" data-role="add-to-links">
#                       <a class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/aziza.tn\/fr\/wishlist\/index\/add\/","data":{"product":2342,"uenc":"aHR0cHM6Ly9heml6YS50bi9mci9ob21l"}}' href="#" title="Ajouter à ma liste d’envie">
#                        <span>
#                         Ajouter à ma liste d’envie
#                        </span>
#                       </a>
#                       <a class="action tocompare" data-post='{"action":"https:\/\/aziza.tn\/fr\/catalog\/product_compare\/add\/","data":{"product":"2342","uenc":"aHR0cHM6Ly9heml6YS50bi9mci9ob21l"}}' href="#" title="Ajouter au comparateur">
#                        <span>
#                         Ajouter au comparateur
#                        </span>
#                       </a>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="product-item">
#                   <div class="product-item-info 2025-04-09 00:00:00">
#                    <a class="product-item-photo" href="https://aziza.tn/fr/10107182.html">
#                     <span class="product-image-container">
#                      <span class="product-image-wrapper">
#                       <img alt="Bouteille  avec couvercle" class="product-image-photo" height="" src="https://aziza.tn/media/catalog/product/cache/b5981f94a096ce8ed249e81adce0f478/1/0/101071821_1956.jpg" width=""/>
#                      </span>
#                     </span>
#                    </a>
#                    <div class="product-item-details">
#                     <div class="product-item-name">
#                      <h3 class="product name product-item-name product-name">
#                       <a class="product-item-link" href="https://aziza.tn/fr/10107182.html" title="Bouteille  avec couvercle">
#                        Bouteille  avec couvercle
#                       </a>
#                       <br/>
# ...
#             $('#catalogues-prochaine-img-f').css({'font-size':'14px !important','color':'#000'});
#             $('#catalogues-en-cours-img-f').css({'font-size':'18px !important','color':'#000'});
#
#         });
#
#     });
#   </script>
#   <script type="text/javascript">
#    require(['jquery'], function ($) {
#
#             $('#catalogues-en-cours-img').click(function(){
#                 $('#grid-v').css('display','none');
#                 $('#grid-vN').css('display','none');
#              $('#grid-a').css('display','block');
#              $('#grid-aN').css('display','block');
#                 $('#grid-d').css('display','none');
#                 $('#grid-dN').css('display','none');
#                 $('#grid-p').css('display','none');
#                 $('#grid-pN').css('display','none');
#
#                 $('.block-catalogues .catalogues-vente .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#                 $('.block-catalogues .catalogues-derniere .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#                 $('.block-catalogues .catalogues-prochaine .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#                 $('.block-catalogues .catalogues-en-cours .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(1.1) translate(0%, 5%)','background': '#fff'});
#
#                 $('.block-catalogues .catalogues-en-cours').css({'background': 'url(../media/wysiwyg/catalogue-semaine.png) no-repeat'});
#                 $('.block-catalogues .catalogues-derniere').css({'background': 'none'});
#                 $('.block-catalogues .catalogues-prochaine').css({'background': 'none'});
#                 $('.block-catalogues .catalogues-vente').css({'background': 'none'});
#
#                 $('#catalogues-derniere-img-f').css({'font-size':'14px !important','color':'#000'});
#                 $('#catalogues-prochaine-img-f').css({'font-size':'14px !important','color':'#000'});
#                 $('#catalogues-vente-img-f').css({'font-size':'14px !important','color':'#000'});
#                 $('#catalogues-en-cours-img-f').css({'font-size':'18px !important','color':'#ffd400'});
#             });
#
#     });
#   </script>
#   <script type="text/javascript">
#    require(['jquery'], function ($) {
#
#         $('#catalogues-prochaine-img').click(function(){
#             $('#grid-v').css('display','none');
#             $('#grid-vN').css('display','none');
#             $('#grid-p').css('display','block');
#             $('#grid-pN').css('display','block');
#             $('#grid-a').css('display','none');
#             $('#grid-aN').css('display','none');
#             $('#grid-d').css('display','none');
#             $('#grid-dN').css('display','none');
#
#             $('.block-catalogues .catalogues-derniere .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#             $('.block-catalogues .catalogues-prochaine .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(1.1) translate(0%, 5%)','background': '#fff'});
#             $('.block-catalogues .catalogues-en-cours .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#             $('.block-catalogues .catalogues-vente .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#
#
#             $('.block-catalogues .catalogues-prochaine').css({'background': 'url(../media/wysiwyg/catalogue-semaine.png) no-repeat'});
#             $('.block-catalogues .catalogues-derniere').css({'background': 'none'});
#             $('.block-catalogues .catalogues-en-cours').css({'background': 'none'});
#             $('.block-catalogues .catalogues-vente').css({'background': 'none'});
#
#             $('#catalogues-vente-img-f').css({'font-size':'14px !important','color':'#000'});
#             $('#catalogues-derniere-img-f').css({'font-size':'14px !important','color':'#000'});
#             $('#catalogues-prochaine-img-f').css({'font-size':'18px !important','color':'#ffd400'});
#             $('#catalogues-en-cours-img-f').css({'font-size':'14px !important','color':'#000'});
#         });
#
#     });
#   </script>
#   <script type="text/javascript">
#    require(['jquery'], function ($) {
#
#         $('#catalogues-vente-img').click(function(){
#             $('#grid-v').css('display','block');
#             $('#grid-vN').css('display','block');
#             $('#grid-p').css('display','none');
#             $('#grid-pN').css('display','none');
#             $('#grid-a').css('display','none');
#             $('#grid-aN').css('display','none');
#             $('#grid-d').css('display','none');
#             $('#grid-dN').css('display','none');
#
#             $('.block-catalogues .catalogues-derniere .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#             $('.block-catalogues .catalogues-prochaine .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#             $('.block-catalogues .catalogues-vente .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(1.1) translate(0%, 5%)','background': '#fff'});
#             $('.block-catalogues .catalogues-en-cours .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#
#
#             $('.block-catalogues .catalogues-vente').css({'background': 'url(../media/wysiwyg/catalogue-semaine.png) no-repeat'});
#             $('.block-catalogues .catalogues-prochaine').css({'background': 'none'});
#             $('.block-catalogues .catalogues-derniere').css({'background': 'none'});
#             $('.block-catalogues .catalogues-en-cours').css({'background': 'none'});
#
#             $('#catalogues-derniere-img-f').css({'font-size':'14px !important','color':'#000'});
#             $('#catalogues-vente-img-f').css({'font-size':'18px !important','color':'#ffd400'});
#             $('#catalogues-prochaine-img-f').css({'font-size':'14px !important','color':'#000'});
#             $('#catalogues-en-cours-img-f').css({'font-size':'14px !important','color':'#000'});
#         });
#
#     });
#   </script>
#   <script type="text/javascript">
#    require(['jquery'], function ($) {
#         $( document ).ready(function() {
#
#             $('#grid-v').css('display','none');
#             $('#grid-vN').css('display','none');
#             $('#grid-a').css('display','block');
#             $('#grid-aN').css('display','block');
#             $('#grid-d').css('display','none');
#             $('#grid-dN').css('display','none');
#             $('#grid-p').css('display','none');
#             $('#grid-pN').css('display','none');
#
#             $('.block-catalogues .catalogues-vente .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#             $('.block-catalogues .catalogues-derniere .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#             $('.block-catalogues .catalogues-prochaine .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(0.9) translate(0%, 4%)','background': '#fff'});
#             $('.block-catalogues .catalogues-en-cours .block-catalogue').css({'-webkit-box-shadow':'1px 5px 8px 0px #fdfdfd','box-shadow':'1px 5px 8px 0px #fdfdfd','transform':'rotateY(0deg) skewY(0deg) translateX(0px)','-webkit-transform':'scale(1.1) translate(0%, 5%)','background': '#fff'});
#
#             $('.block-catalogues .catalogues-en-cours').css({'background': 'url(../media/wysiwyg/catalogue-semaine.png) no-repeat'});
#             $('.block-catalogues .catalogues-derniere').css({'background': 'none'});
#             $('.block-catalogues .catalogues-prochaine').css({'background': 'none'});
#             $('.block-catalogues .catalogues-vente').css({'background': 'none'});
#
#             $('#catalogues-derniere-img-f').css({'font-size':'14px !important','color':'#000'});
#             $('#catalogues-prochaine-img-f').css({'font-size':'14px !important','color':'#000'});
#             $('#catalogues-vente-img-f').css({'font-size':'14px !important','color':'#000'});
#             $('#catalogues-en-cours-img-f').css({'font-size':'18px !important','color':'#ffd400'});
#         });
#
#
#     });
#   </script>
#   <script>
#    window.onscroll = function() {scrollFunction()};
#
# function scrollFunction() {
# if (document.body.scrollTop > 50 || document.documentElement.scrollTop > 50) {
# document.getElementById("fixed").style.top = "92px";
# } else {
# document.getElementById("fixed").style.top = "-92px";
# }
# }
#
#
# var header = document.getElementById("topheader");
# var btns = header.getElementsByClassName("btn");
# for (var i = 0; i < btns.length; i++) {
# btns[i].addEventListener("click", function() {
# var current = document.getElementsByClassName("active");
# current[0].className = current[0].className.replace(" active", "");
# this.className += " active";
# });
# }
#
#  function openCity(evt, cityName) {
#   var i, tabcontent, tablinks;
#   tabcontent = document.getElementsByClassName("tabcontent");
#   for (i = 0; i < tabcontent.length; i++) {
#     tabcontent[i].style.display = "none";
#   }
#   tablinks = document.getElementsByClassName("tablinks");
#   for (i = 0; i < tablinks.length; i++) {
#     tablinks[i].className = tablinks[i].className.replace(" active", "");
#   }
#   document.getElementById(cityName).style.display = "block";
#   evt.currentTarget.className += " active";
# }
#
# // Get the element with id="defaultOpen" and click on it
# document.getElementById("defaultOpen").click();
#   </script>
#   <script type="text/javascript">
#    require(["jquery"],function($){
#     jQuery(".increaseqty").click(function(e){
#         e.preventDefault();
#         var qty = jQuery(this).closest("div.control").find("input");
#         var newqty = parseInt(qty.val())+parseInt(1);
#         qty.val(newqty);
#         var val = qty.val();
#         var label = jQuery.mage.__('');
#         var changeQty = parseInt(val) + label;
#         qtyLabel = jQuery(this).closest("div.control").find("span");
#         jQuery(qtyLabel).text(changeQty);
#         return false;
#     });
#
#     jQuery(".decreaseqty").click(function(){
#         var qty = jQuery(this).closest("div.control").find("input");
#         var newqty = parseInt(qty.val())-parseInt(1);
#         if(newqty < 1){
#             return false;
#         }
#         qty.val(newqty);
#         var val = qty.val();
#         var label = jQuery.mage.__('');
#         var changeQty = parseInt(val) + label;
#         qtyLabel = jQuery(this).closest("div.control").find("span");
#         jQuery(qtyLabel).text(changeQty);
#         return false;
#
#     });
# });
#   </script>
#   <script type="text/javascript">
#    require(['jquery', 'jquery/ui', 'Et_OrderTracking/js/jquery.mask.min'], function($){
#         $( document ).ready(function() {
#             jQuery('[name="telephone"]').mask('00 00 00 00');
#             jQuery('[name="postcode"]').mask('0000');
#             jQuery('[name="cin"]').mask('00000000');
#
#             if(isIpadOS()) {
#                 $('body').addClass('ipad');
#             } else {
#                 $('body').addClass('not-ipad');
#             }
#         });
#     });
#
#     function isIOS() {
#         if (/iPad|iPhone|iPod/.test(navigator.platform)) {
#             return true;
#         } else {
#             return navigator.maxTouchPoints &&
#                 navigator.maxTouchPoints > 2 &&
#                 /MacIntel/.test(navigator.platform);
#         }
#     }
#
#     function isIpadOS() {
#         return navigator.maxTouchPoints &&
#             navigator.maxTouchPoints > 2 &&
#             /MacIntel/.test(navigator.platform);
#     }
#   </script>
#   <script type="text/x-magento-init">
#    {
#             "*": {
#                 "Magento_Ui/js/core/app": {
#                     "components": {
#                         "storage-manager": {
#                             "component": "Magento_Catalog/js/storage-manager",
#                             "appendTo": "",
#                             "storagesConfiguration" : {"recently_viewed_product":{"requestConfig":{"syncUrl":"https:\/\/aziza.tn\/fr\/catalog\/product\/frontend_action_synchronize\/"},"lifetime":"1000","allowToSendRequest":null},"recently_compared_product":{"requestConfig":{"syncUrl":"https:\/\/aziza.tn\/fr\/catalog\/product\/frontend_action_synchronize\/"},"lifetime":"1000","allowToSendRequest":null},"product_data_storage":{"updateRequestConfig":{"url":"https:\/\/aziza.tn\/fr\/rest\/fr\/V1\/products-render-info"},"requestConfig":{"syncUrl":"https:\/\/aziza.tn\/fr\/catalog\/product\/frontend_action_synchronize\/"},"allowToSendRequest":null}}                        }
#                     }
#                 }
#             }
#         }
#   </script>
#   <script type="text/javascript">
#    require([
#     'jquery',
#     'quickView',
#     'domReady!'
# ], function ($, cartQuickView) {
#     var quickViewCf = {
#         isQuickView: true,
#         isAjaxCart: true,
#         product_container: '.product-item-info',
#         button_container: '.product-item-photo',
#         label_button: 'Quick View',
#         base_url: 'https://aziza.tn/fr/'
#     }
#     $(quickViewCf.product_container).cartQuickView(quickViewCf);
#     $(document).on("afterAjaxProductsLoaded", function (event) {
#         $(quickViewCf.product_container).cartQuickView(quickViewCf);
#     });
# });
#   </script>
#   <script type="text/x-magento-init">
#    {
# 	"#maincontent": {
# 		"Sm_CartQuickPro/js/custom-addtocart": {
# 			"isEnabled": true,
# 			"isAjaxCart": true,
# 			"urlLogin": "https://aziza.tn/fr/customer/account/login/",
# 			"isLoggedIn": false,
# 			"addUrl": "https://aziza.tn/fr/cartquickpro/cart/add",
# 			"isUpdateConfigure": false,
# 			"isCompareIndex": false,
# 			"isProductView": false,
# 			"isCheckoutPage":  false,
# 			"isWishlistPage": false,
# 			"urlCurrent": "https://aziza.tn/fr/home",
# 			"countDownNumber": 10		}
# 	}
# }
#   </script>
#   <script>
#    require(['jquery', 'jquery/ui' ,'qtychange'], function($){
# //your js code here
#
#     });
#   </script>
#  </body>
# </html>
