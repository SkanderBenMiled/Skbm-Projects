# %%
# !pip install ydata-profiling

# %% [markdown]
# ydata-profiling is a Python library or package, creates a thorough report on a DataFrame, showing the number of rows and columns, missing values, data types, and other statistics. With it, data issues and outliers can be easily detected, and the report provides summary statistics and visualizations.
#
# The report generated typically includes:
#
# Overview: Summary statistics for all columns, including the number of rows, missing values, and data types.
#
# Variables: Information about each column, including the number of unique values, missing values, and the top frequent values.
#
# Correlations: Correlation matrix and heatmap, showing the relationship between different variables.
#
# Distribution: Histograms and kernel density plots for each column, show the distribution of values.
#
# Categorical Variables: Bar plots for categorical variables, showing the frequency of each category.
#
# Numerical Variables: Box plots for numerical variables, show the distribution of values and outliers.
#
# Text: Information about text columns, including the number of characters and words.
#
# File: Information about file columns, including the number of files, and the size of each file.
#
# High-Cardinality: Information about high-cardinality categorical variables, including their most frequent values.
#
# Sample: A sample of the data, with the first and last few rows displayed. It is worth noting that the report is interactive and you can drill down on each section for more details.

# %% [markdown]
# # Dataset 1

# %% [markdown]
# dataset link : https://drive.google.com/file/d/1GJKt6wqzDN8i2D-kaBkCWKxztAosFi8g/view

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
Popular_baby_names_df = pd.read_csv('/kaggle/input/baby-names/Popular_Baby_Names (4).txt')

# %%
Popular_baby_names_df.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
#
#    Count  Rank
# 0    119     1
# 1    106     2
# 2     93     3
# 3     89     4
# 4     75     5

# %%
Popular_baby_names_df.shape
# Out:
# (11345, 6)

# %%
# Generate the profile report
profile = ProfileReport(Popular_baby_names_df, title='Pandas Profiling Report')

# %%
# profile

# %%
# Or generate an HTML report
profile.to_file("your_report_name.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Display the report
profile.to_notebook_iframe()

# %% [markdown]
# # Dataset 2

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# https://drive.google.com/file/d/1SEm31LiDrmMgQ3ZHIlsKEw434e2a8N0L/view
#
# https://drive.google.com/file/d/1NRYbZIWrPG_F0JzqAECy1uiv2PKfCtr8/view

# %%
data1 = pd.read_csv("/content/ds_salaries.csv")

# %%
data1.head()

# %%
data1.info()

# %%
data1.describe(include='all')

# %%
profile = ProfileReport(data1)

# %%
profile

# %%
profile.to_file('EDA.json')

# %%
profile.to_file('EDA.html')

# %%
#add metadata
profile = ProfileReport(data1,
                        title="Data Science Salaries",
                        dataset = {
                            "description": "  salaries of jobs in the data science domain",
                            "url": "kaggle.com"
                        })
profile

# %%
profile.to_widgets()

# %% [markdown]
# # compare

# %%
data2 = pd.read_csv("/content/ds_salaries_2023.csv")
data2.head()

# %%
report = ProfileReport(data2,title='DS 2023')
# report

# %%
report

# %%
comp_report = profile.compare(report)
# comp_report

# %%
comp_report.to_file("your_report_name.html")

# %% [markdown]
# # Exercises :

# %% [markdown]
# checkpoint 1 :

# %% [markdown]
# dataset link : https://drive.google.com/file/d/1m7005DlhJE3xe42sy8nMV2Xop2GXw3tF/view

# %% [markdown]
# checkpoint 2 :

# %% [markdown]
# link dataset : https://drive.google.com/file/d/1W7WFOiCZu9qFeKFhM0_1bV7BQWsgSuMv/view
