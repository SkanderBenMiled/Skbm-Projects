# %% [markdown]
# # Reading In Files

# %%
import pandas as pd

# %%
path_csv="/content/countries of the world.csv"
path_json="/content/json_sample.json"
path_txt = "/content/countries of the world.txt"
path_excel = "/content/world_population_excel_workbook.xlsx"

# %%
df = pd.read_csv(path_csv)
df

# %%
df = pd.read_csv(path_txt, sep = '\t')
df

# %%
df = pd.read_json(path_json)
df

# %%
df = pd.read_excel(path_excel)
df

# %%
df = pd.read_excel(path_excel, sheet_name='world_population')
df

# %%
df2 = pd.read_excel(path_excel, sheet_name = 'Sheet1')
df2

# %%
df2.info()

# %%
df2.shape

# %%
df2.head()

# %%
df2.tail(10)

# %%
df2['Rank']

# %%
df2

# %% [markdown]
# # Pandas Series and Dataframes

# %%
import numpy as np

# %%
my_list = [10,25,35]

x = np.array(my_list)

print(x)

# %%
type(x)

# %%
pd.Series(my_list)

# %%
index_values = ['Best','Second Best','Third Best']
my_list = [10,25,35]

one = pd.Series(data=my_list, index=index_values)

# %%
one

# %%
index_values = ['Best','Second Best','Forth Best']
my_list = [10,25,40]

two = pd.Series(data=my_list,index=index_values)

# %%
two

# %% [markdown]
# **Constructing DataFrame**
# - DataFrame is a data structure constructed using pandas library

# %%
df = pd.DataFrame(
    data = (np.arange(0,25).reshape(5,5)),
    index=["Row 1","Row 2","Row 3","Row 4","Row 5"],
    columns = ["Col 1","Col 2","Col 3","Col 4","Col 5"]
)
df

# %%
ice_cream = [['MCC',1],['Butterscotch',2],['Butter Pecan',3]]

ice_cream_dataframe = pd.DataFrame(ice_cream,index=['Flavor 1','Flavor 2','Flavor 3'], columns=('Flavor','Scoops'))

ice_cream_dataframe

# %%
ice_cream = ['MCC','Butterscotch','Butter Pecan']
scoops = [1,2,3]

dataframe_icecream = {'Flavor': ice_cream, 'Scoops': scoops}

ice_cream_dataframe = pd.DataFrame(dataframe_icecream,index=['Flavor 1','Flavor 2','Flavor 3'] )
ice_cream_dataframe

# %%
df.head() # by default top 5 records

# %%
df.tail(2)

# %%
type(df)

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# **Indexing**
# - using columnname
# - using rowindex i.e.[loc]
# - rowindex column index [iloc]

# %%
df.head()

# %% [markdown]
# **Using column name**

# %%
df[['Col 1','Col 2','Col 3']]

# %%
df['Col 1']

# %%
type(df['Col 1'])

# %%
# If we take more than one row or more than one col of data => dataframe
# one row or one column => Series

# %% [markdown]
# **Using loc**

# %%
df.loc['Row 1']

# %%
df.loc[['Row 1','Row 2']]

# %% [markdown]
# **Using iloc**
# - df.iloc[row,column]

# %%
df.iloc[2:4,0:2]

# %%
df.iloc[:,:]

# %%
df.iloc[0:2,:]

# %%
# Converts dataframe into arrays
df.iloc[:,:].values

# %% [markdown]
# **Operations**

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
df1 = pd.DataFrame(data = [[1,np.nan,2],[1,3,4]],
                   index=["row 1","row2"],
                  columns = ["col 1","col 2","col 3"])
df1

# %%
df1.isnull().sum()

# %%
df1.isnull().sum()==0

# %%
df1['col 1'].value_counts()

# %%
df1['col 3'].unique()

# %%
df1['col 1'].unique()

# %%
df1

# %%
df1['col 2']>2

# %%
# Conditional indexing
df1[df1['col 2']>2]

# %% [markdown]
# # Ex

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
